# %%
# !git clone https://github.com/yourrepo/OpenClaw-RL.git
# !pip install -r OpenClaw-RL/requirements.txt
# !python OpenClaw-RL/start_combine_lora.py
# !curl -v -H 'Content-Type: application/json' -d '{"data": "Some test data"}' http://localhost:3000/test
# !cloudflared tunnel --url http://localhost:3000
# !cat OpenClaw-RL/logs/tunnel.log
# !pkill -f cloudflared

# %% [markdown]
# # OpenClaw-RL Combine Qwen 4B Colab Demo
# This notebook provides a minimal demonstration for combining Qwen 4B in Colab. You can follow the sections below to set everything up, run a health check, and conduct a test request.

# %%
# !curl -f http://localhost:3000/health
# Out:
# Health Check: Running
